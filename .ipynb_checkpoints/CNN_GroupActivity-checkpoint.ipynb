# %% [markdown]
# ## Group Activity 2: CNN Image Classification Using Real Life Images

# %% [markdown]
# Castillo, Alyssa Celine C.; Necesito, Mark Ivan L.; Soriano, Toni Rose M.; BSECE-4A

# %% [markdown]
# Create a CNN Image Classification Model that can classify real-life images into 5 different classes namely: buildings, forest, glacier, mountain, sea, and street. Link for the dataset can be downloaded here: https://drive.google.com/file/d/14kPJ1o-AOE3B5vEnyzejAGRzuhm3TKja/view?usp=sharing.

# %% [markdown]
# ## Determining File Paths

# %%
import os
data_dir = 'C:\\School\\Anaconda\\CNNActivity'

# %%
os.listdir(data_dir)
# Out:
# ['new_sample', 'test', 'train']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib.image import imread

# %%
test_path= data_dir+'\\test\\'
train_path= data_dir+'\\train\\'

# %%
os.listdir(test_path)
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
os.listdir(train_path+'glacier')[0]
# Out:
# '10.jpg'

# %%
glacier1 = train_path + '\\glacier\\' + '10.jpg'

# %%
glacier1_img = imread(glacier1)

# %%
plt.imshow(glacier1_img)

# %%
os.listdir(train_path+'buildings')[0]
# Out:
# '0.jpg'

# %%
buildings = train_path + '\\buildings\\' + '0.jpg'

# %%
buildings_img = imread(buildings)

# %%
plt.imshow(buildings_img)

# %%
os.listdir(train_path+'forest')[0]
# Out:
# '10007.jpg'

# %%
forest = train_path + '\\forest\\' + '10007.jpg'

# %%
forest_img = imread(forest)

# %%
plt.imshow(forest_img)

# %%
os.listdir(train_path+'mountain')[0]
# Out:
# '10000.jpg'

# %%
mountain = train_path + '\\mountain\\' + '10000.jpg'

# %%
mountain_img = imread(mountain)

# %%
plt.imshow(mountain_img)

# %%
os.listdir(train_path+'sea')[0]
# Out:
# '1.jpg'

# %%
sea = train_path + '\\sea\\' + '1.jpg'

# %%
sea_img = imread(sea)

# %%
plt.imshow(sea_img)

# %%
os.listdir(train_path+'street')[0]
# Out:
# '1000.jpg'

# %%
street = train_path + '\\street\\' + '1000.jpg'

# %%
street_img = imread(street)

# %%
plt.imshow(street_img)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
buildings_img.shape
# Out:
# (150, 150, 3)

# %%
forest_img.shape
# Out:
# (150, 150, 3)

# %%
glacier1_img.shape
# Out:
# (150, 150, 3)

# %%
sea_img.shape
# Out:
# (150, 150, 3)

# %%
mountain_img.shape
# Out:
# (150, 150, 3)

# %%
street_img.shape
# Out:
# (150, 150, 3)

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\street'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\street'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.98446683459278

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\buildings'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\buildings'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.9881332724783

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\forest'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\forest'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.89476001761338

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\mountain'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\mountain'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.8638535031847

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\glacier'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\glacier'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.78535773710482

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\sea'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\sea'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.94678979771328

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
len(os.listdir(train_path+'buildings'))
# Out:
# 2191

# %%
len(os.listdir(train_path+'forest'))
# Out:
# 2271

# %%
len(os.listdir(train_path+'glacier'))
# Out:
# 2404

# %%
len(os.listdir(train_path+'sea'))
# Out:
# 2274

# %%
len(os.listdir(train_path+'mountain'))
# Out:
# 2512

# %%
len(os.listdir(train_path+'street'))
# Out:
# 2382

# %%
len(os.listdir(test_path+'buildings'))
# Out:
# 437

# %%
len(os.listdir(test_path+'forest'))
# Out:
# 474

# %%
len(os.listdir(test_path+'glacier'))
# Out:
# 553

# %%
len(os.listdir(test_path+'sea'))
# Out:
# 510

# %%
len(os.listdir(test_path+'mountain'))
# Out:
# 525

# %%
len(os.listdir(test_path+'street'))
# Out:
# 501

# %%
image_shape = (150,150,3)

# %% [markdown]
# ## Data Preparation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(
                               shear_range=0.3, # Shear means cutting away part of the image (max 10%)
                               zoom_range=0.3, # Zoom in by 10% max
                               horizontal_flip=True, # Allo horizontal flipping
                               rescale = 1/255
                              )

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 14034 images belonging to 6 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
plt.imshow(street_img)

# %%
trans = image_gen.random_transform(street_img)
plt.imshow(trans)

# %% [markdown]
# ## Building the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Activation

# %%
model = Sequential()

model.add(Conv2D(filters=32, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=32, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=128, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(64,activation='relu'))
model.add(Dense(6))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               802944
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 390
# _________________________________________________________________
# activation (Activation)      (None, 6)                 0
# =================================================================
# Total params: 914,086
# Trainable params: 914,086
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=0)

# %% [markdown]
# ## Model Training

# %%
batch_size = 20

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=image_shape[:2],
                                                color_mode='rgb',
                                               batch_size=batch_size,
                                                class_mode='categorical')
# Out:
# Found 14034 images belonging to 6 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=image_shape[:2],
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical',
                                              shuffle = False)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
train_image_gen.class_indices
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
results = model.fit_generator(train_image_gen,epochs=20,
                              validation_data=test_image_gen,
                             callbacks=[early_stop])
# Out:
# Epoch 1/20
# 702/702 [==============================] - 423s 603ms/step - loss: 1.1092 - accuracy: 0.5475 - val_loss: 0.9189 - val_accuracy: 0.6403
# Epoch 2/20
# 702/702 [==============================] - 438s 624ms/step - loss: 0.8542 - accuracy: 0.6774 - val_loss: 0.7265 - val_accuracy: 0.7210
# Epoch 3/20
# 702/702 [==============================] - 395s 563ms/step - loss: 0.7306 - accuracy: 0.7256 - val_loss: 0.7202 - val_accuracy: 0.7237
# Epoch 4/20
# 702/702 [==============================] - 360s 513ms/step - loss: 0.6587 - accuracy: 0.7576 - val_loss: 0.5989 - val_accuracy: 0.7763
# Epoch 5/20
# 702/702 [==============================] - 365s 520ms/step - loss: 0.6044 - accuracy: 0.7854 - val_loss: 0.5872 - val_accuracy: 0.7860
# Epoch 6/20
# 702/702 [==============================] - 386s 550ms/step - loss: 0.5619 - accuracy: 0.7971 - val_loss: 0.5454 - val_accuracy: 0.8113
# Epoch 7/20
# 702/702 [==============================] - 394s 562ms/step - loss: 0.5343 - accuracy: 0.8113 - val_loss: 0.5234 - val_accuracy: 0.8073
# Epoch 8/20
# 702/702 [==============================] - 371s 528ms/step - loss: 0.5096 - accuracy: 0.8236 - val_loss: 0.4934 - val_accuracy: 0.8283
# Epoch 9/20
# 702/702 [==============================] - 416s 592ms/step - loss: 0.4743 - accuracy: 0.8306 - val_loss: 0.4690 - val_accuracy: 0.8387
# Epoch 10/20
# 702/702 [==============================] - 392s 559ms/step - loss: 0.4545 - accuracy: 0.8390 - val_loss: 0.4844 - val_accuracy: 0.8337

# %% [markdown]
# ## Model Evaluation

# %%
metrics = pd.DataFrame(model.history.history)

# %%
metrics
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  1.109149  0.547527  0.918923      0.640333
# 1  0.854259  0.677355  0.726539      0.721000
# 2  0.730650  0.725595  0.720203      0.723667
# 3  0.658683  0.757589  0.598855      0.776333
# 4  0.604460  0.785378  0.587197      0.786000
# 5  0.561816  0.797064  0.545438      0.811333
# 6  0.534370  0.811315  0.523379      0.807333
# 7  0.509562  0.823571  0.493405      0.828333
# 8  0.474486  0.830626  0.469031      0.838667
# 9  0.454309  0.839034  0.484370      0.833667

# %%
metrics[['accuracy','val_accuracy']].plot()
# Out:
# <AxesSubplot:>

# %%
metrics[['loss','val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
print(model.metrics_names)
print(model.evaluate(test_image_gen,verbose=0))
# Out:
# ['loss', 'accuracy']
# [0.47128068846960863, 0.837]

# %%
# CODE HERE
model.save("CNN_Activity.h5")

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
predictions = model.predict(test_image_gen)

# %%
pred = np.argmax(predictions, axis = 1)

# %%
confusion_matrix(test_image_gen.classes,pred)
# Out:
# array([[328,   7,   3,   8,  36,  55],
#        [  0, 455,   1,   7,   3,   8],
#        [  1,   3, 416,  57,  70,   6],
#        [  2,   4,  62, 409,  48,   0],
#        [  3,   5,  20,  15, 467,   0],
#        [ 21,  12,   6,   4,  24, 434]], dtype=int64)

# %%
print(classification_report(test_image_gen.classes,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.75      0.83       437
#            1       0.94      0.96      0.95       474
#            2       0.82      0.75      0.78       553
#            3       0.82      0.78      0.80       525
#            4       0.72      0.92      0.81       510
#            5       0.86      0.87      0.86       501
#
#     accuracy                           0.84      3000
#    macro avg       0.85      0.84      0.84      3000
# weighted avg       0.84      0.84      0.84      3000

# %% [markdown]
# ## New Image Prediction

# %%
from tensorflow.keras.preprocessing import image

# %%
dir_path = 'C:\\School\\Anaconda\\CNNActivity\\new_sample'

# %%
os.listdir(dir_path)[75]
# Out:
# '10261.jpg'

# %%
sample = dir_path + '\\10261.jpg'

# %%
sample = image.load_img(sample,target_size=image_shape);
sample
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x21984BC1248>

# %%
sample_img = image.img_to_array(sample);
sample_img.shape
# Out:
# (150, 150, 3)

# %%
sample_img = sample_img.reshape(1,150,150,3)

# %%
predicted = model.predict(sample_img)

# %%
np.argmax(predicted)
# Out:
# 0

# %%
plt.figure(figsize=(20,20))

class_names = ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']


for i in range(30):
    ax = plt.subplot(6, 5, i + 1)
    img = os.path.join(dir_path, os.listdir(dir_path)[i])
    img = image.load_img(img)
    img_array = image.img_to_array(img)     
    img_array = img_array
    input_img = np.expand_dims(img_array, axis=0)
    prediction = model.predict(input_img)
    label = np.argmax(prediction)
    plt.imshow(img)
    plt.title(class_names[label])
    plt.axis('off')
