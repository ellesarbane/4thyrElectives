# %%
import os
data_dir = 'C:\\School\\Anaconda\\CNNActivity'

# %%
os.listdir(data_dir)
# Out:
# ['new_sample', 'test', 'train']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib.image import imread

# %%
test_path= data_dir+'\\test\\'
train_path= data_dir+'\\train\\'

# %%
os.listdir(test_path)
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
os.listdir(train_path+'glacier')[0]
# Out:
# '10.jpg'

# %%
glacier1 = train_path + '\\glacier\\' + '10.jpg'

# %%
glacier1_img = imread(glacier1)

# %%
plt.imshow(glacier1_img)

# %%
os.listdir(train_path+'buildings')[0]
# Out:
# '0.jpg'

# %%
buildings = train_path + '\\buildings\\' + '0.jpg'

# %%
buildings_img = imread(buildings)

# %%
plt.imshow(buildings_img)

# %%
os.listdir(train_path+'forest')[0]
# Out:
# '10007.jpg'

# %%
forest = train_path + '\\forest\\' + '10007.jpg'

# %%
forest_img = imread(forest)

# %%
plt.imshow(forest_img)

# %%
os.listdir(train_path+'mountain')[0]
# Out:
# '10000.jpg'

# %%
mountain = train_path + '\\mountain\\' + '10000.jpg'

# %%
mountain_img = imread(mountain)

# %%
plt.imshow(mountain_img)

# %%
os.listdir(train_path+'sea')[0]
# Out:
# '1.jpg'

# %%
sea = train_path + '\\sea\\' + '1.jpg'

# %%
sea_img = imread(sea)

# %%
plt.imshow(sea_img)

# %%
os.listdir(train_path+'street')[0]
# Out:
# '1000.jpg'

# %%
street = train_path + '\\street\\' + '1000.jpg'

# %%
street_img = imread(street)

# %%
plt.imshow(street_img)

# %%
buildings_img.shape
# Out:
# (150, 150, 3)

# %%
forest_img.shape
# Out:
# (150, 150, 3)

# %%
glacier1_img.shape
# Out:
# (150, 150, 3)

# %%
sea_img.shape
# Out:
# (150, 150, 3)

# %%
mountain_img.shape
# Out:
# (150, 150, 3)

# %%
street_img.shape
# Out:
# (150, 150, 3)

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\street'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\street'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.98446683459278

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
len(os.listdir(train_path+'buildings'))
# Out:
# 2191

# %%
len(os.listdir(train_path+'forest'))
# Out:
# 2271

# %%
len(os.listdir(train_path+'glacier'))
# Out:
# 2404

# %%
len(os.listdir(train_path+'sea'))
# Out:
# 2274

# %%
len(os.listdir(train_path+'mountain'))
# Out:
# 2512

# %%
len(os.listdir(train_path+'street'))
# Out:
# 2382

# %%
len(os.listdir(test_path+'buildings'))
# Out:
# 437

# %%
len(os.listdir(test_path+'forest'))
# Out:
# 474

# %%
len(os.listdir(test_path+'glacier'))
# Out:
# 553

# %%
len(os.listdir(test_path+'sea'))
# Out:
# 510

# %%
len(os.listdir(test_path+'mountain'))
# Out:
# 525

# %%
len(os.listdir(test_path+'street'))
# Out:
# 501

# %%
image_shape = (150,150,3)

# %%
len(dim1)
# Out:
# 2382

# %% [markdown]
# ## Data Preparation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=20, # rotate the image 20 degrees
                               width_shift_range=0.10, # Shift the pic width by a max of 5%
                               height_shift_range=0.10, # Shift the pic height by a max of 5%
                               shear_range=0.1, # Shear means cutting away part of the image (max 10%)
                               zoom_range=0.1, # Zoom in by 10% max
                               horizontal_flip=True, # Allo horizontal flipping
                               fill_mode='nearest', # Fill in missing pixels with the nearest filled value
                               rescale = 1/255
                              )

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 14034 images belonging to 6 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 3000 images belonging to 6 classes.

# %% [markdown]
# ## Building the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Activation

# %%
model = Sequential()

model.add(Conv2D(filters=32, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))

model.add(Dense(6))
model.add(Activation('softmax'))

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18496)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               2367616
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# _________________________________________________________________
# activation (Activation)      (None, 6)                 0
# =================================================================
# Total params: 2,424,710
# Trainable params: 2,424,710
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %% [markdown]
# ## Model Training

# %%
batch_size = 16

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=image_shape[:2],
                                                color_mode='rgb',
                                               batch_size=batch_size,
                                                class_mode='sparse')
# Out:
# Found 14034 images belonging to 6 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=image_shape[:2],
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='sparse',shuffle=False)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
train_image_gen.class_indices
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
results = model.fit_generator(train_image_gen,epochs=20,
                              validation_data=test_image_gen,
                             callbacks=[early_stop])
# Out:
# Epoch 1/20
# 878/878 [==============================] - 376s 428ms/step - loss: 1.0166 - accuracy: 0.6023 - val_loss: 1.0504 - val_accuracy: 0.6203
# Epoch 2/20
# 878/878 [==============================] - 410s 467ms/step - loss: 0.7612 - accuracy: 0.7178 - val_loss: 0.7327 - val_accuracy: 0.7363
# Epoch 3/20
# 878/878 [==============================] - 407s 463ms/step - loss: 0.6551 - accuracy: 0.7621 - val_loss: 0.6480 - val_accuracy: 0.7700
# Epoch 4/20
# 878/878 [==============================] - 383s 436ms/step - loss: 0.6002 - accuracy: 0.7805 - val_loss: 0.5849 - val_accuracy: 0.7900
# Epoch 5/20
# 878/878 [==============================] - 381s 434ms/step - loss: 0.5458 - accuracy: 0.8011 - val_loss: 0.6078 - val_accuracy: 0.7860
# Epoch 6/20
# 878/878 [==============================] - 415s 472ms/step - loss: 0.5247 - accuracy: 0.8127 - val_loss: 0.5483 - val_accuracy: 0.8090
# Epoch 7/20
# 878/878 [==============================] - 361s 411ms/step - loss: 0.4991 - accuracy: 0.8198 - val_loss: 0.5069 - val_accuracy: 0.8207
# Epoch 8/20
# 878/878 [==============================] - 354s 404ms/step - loss: 0.4755 - accuracy: 0.8286 - val_loss: 0.5087 - val_accuracy: 0.8257
# Epoch 9/20
# 878/878 [==============================] - 353s 402ms/step - loss: 0.4564 - accuracy: 0.8386 - val_loss: 0.4868 - val_accuracy: 0.8160
# Epoch 10/20
# 878/878 [==============================] - 389s 443ms/step - loss: 0.4547 - accuracy: 0.8392 - val_loss: 0.4588 - val_accuracy: 0.8437
# Epoch 11/20
# 878/878 [==============================] - 397s 452ms/step - loss: 0.4438 - accuracy: 0.8396 - val_loss: 0.4839 - val_accuracy: 0.8287
# Epoch 12/20
# 878/878 [==============================] - 377s 429ms/step - loss: 0.4157 - accuracy: 0.8523 - val_loss: 0.4592 - val_accuracy: 0.8440

# %%
model.save('SavedModelCNNActivity')
# Out:
# INFO:tensorflow:Assets written to: SavedModelCNNActivity\assets

# %%
from tensorflow.keras.models import load_model
model = load_model('SavedModelCNNActivity')

# %% [markdown]
# ## Model Evaluation

# %%
pred_probabilities = model.predict_generator(test_image_gen)
pred = np.argmax(pred_probabilities, axis = 1)

# %%
pred
# Out:
# array([0, 0, 0, ..., 3, 0, 5], dtype=int64)

# %%
train_image_gen.class_indices
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(test_image_gen.classes,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82       437
#            1       0.96      0.97      0.96       474
#            2       0.78      0.81      0.80       553
#            3       0.78      0.78      0.78       525
#            4       0.85      0.78      0.81       510
#            5       0.88      0.81      0.85       501
#
#     accuracy                           0.83      3000
#    macro avg       0.84      0.84      0.84      3000
# weighted avg       0.84      0.83      0.83      3000

# %%
confusion_matrix(test_image_gen.classes,pred)
# Out:
# array([[385,   2,   2,   3,   8,  37],
#        [  5, 458,   1,   3,   1,   6],
#        [ 13,   4, 449,  61,  22,   4],
#        [  8,   3,  72, 407,  34,   1],
#        [ 15,   3,  45,  44, 396,   7],
#        [ 72,   7,   4,   5,   5, 408]], dtype=int64)

# %%
metrics = pd.DataFrame(model.history.history)
metrics
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_792/964866579.py in <module>
# ----> 1 metrics = pd.DataFrame(model.history.history)
#       2 metrics
#
# AttributeError: 'Sequential' object has no attribute 'history'

# %% [markdown]
# ## Predicting out-of-sample images

# %%
from tensorflow.keras.preprocessing import image

# %%
dir_path = 'C:\\School\\Anaconda\\CNNActivity\\new_sample'

# %%
os.listdir(dir_path)[100]
# Out:
# '10342.jpg'

# %%
sample = dir_path + '\\14.jpg'

# %%
sample = image.load_img(sample,target_size=image_shape)

# %%
sample
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x1C382195F48>

# %%
sample_img = image.img_to_array(sample)

# %%
sample_img.shape
# Out:
# (150, 150, 3)

# %%
sample_img = sample_img.reshape(1,150,150,3)

# %%
predicted = model.predict(sample_img)

# %%
np.argmax(predicted)
# Out:
# 5

# %%
plt.figure(figsize=(20,20))

class_names = ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']


for i in :
    ax = plt.subplot(5, 5, i + 1)
    img = os.path.join(dir_path, os.listdir(dir_path)[i])
    img = image.load_img(img)
    img_array = image.img_to_array(img)     
    img_array = img_array
    input_img = np.expand_dims(img_array, axis=0)
    prediction = model.predict(input_img)
    label = np.argmax(prediction)
    plt.imshow(img)
    plt.title(class_names[label])
    plt.axis('off')
