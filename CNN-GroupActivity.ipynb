# %% [markdown]
# ## Group Activity 2: CNN Image Classification Using Real Life Images

# %% [markdown]
# Castillo, Alyssa Celine C.; Necesito, Mark Ivan L.; Soriano, Toni Rose M.; BSECE-4A

# %% [markdown]
# Create a CNN Image Classification Model that can classify real-life images into 5 different classes namely: buildings, forest, glacier, mountain, sea, and street. Link for the dataset can be downloaded here: https://drive.google.com/file/d/14kPJ1o-AOE3B5vEnyzejAGRzuhm3TKja/view?usp=sharing.

# %% [markdown]
# ## Determining File Paths

# %%
import os
data_dir = 'C:\\School\\Anaconda\\CNNActivity'

# %%
os.listdir(data_dir)
# Out:
# ['new_sample', 'test', 'train']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from matplotlib.image import imread

# %%
test_path= data_dir+'\\test\\'
train_path= data_dir+'\\train\\'

# %%
os.listdir(test_path)
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
os.listdir(train_path+'glacier')[0]
# Out:
# '10.jpg'

# %%
glacier1 = train_path + '\\glacier\\' + '10.jpg'

# %%
glacier1_img = imread(glacier1)

# %%
plt.imshow(glacier1_img)

# %%
os.listdir(train_path+'buildings')[0]
# Out:
# '0.jpg'

# %%
buildings = train_path + '\\buildings\\' + '0.jpg'

# %%
buildings_img = imread(buildings)

# %%
plt.imshow(buildings_img)

# %%
os.listdir(train_path+'forest')[0]
# Out:
# '10007.jpg'

# %%
forest = train_path + '\\forest\\' + '10007.jpg'

# %%
forest_img = imread(forest)

# %%
plt.imshow(forest_img)

# %%
os.listdir(train_path+'mountain')[0]
# Out:
# '10000.jpg'

# %%
mountain = train_path + '\\mountain\\' + '10000.jpg'

# %%
mountain_img = imread(mountain)

# %%
plt.imshow(mountain_img)

# %%
os.listdir(train_path+'sea')[0]
# Out:
# '1.jpg'

# %%
sea = train_path + '\\sea\\' + '1.jpg'

# %%
sea_img = imread(sea)

# %%
plt.imshow(sea_img)

# %%
os.listdir(train_path+'street')[0]
# Out:
# '1000.jpg'

# %%
street = train_path + '\\street\\' + '1000.jpg'

# %%
street_img = imread(street)

# %%
plt.imshow(street_img)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
buildings_img.shape
# Out:
# (150, 150, 3)

# %%
forest_img.shape
# Out:
# (150, 150, 3)

# %%
glacier1_img.shape
# Out:
# (150, 150, 3)

# %%
sea_img.shape
# Out:
# (150, 150, 3)

# %%
mountain_img.shape
# Out:
# (150, 150, 3)

# %%
street_img.shape
# Out:
# (150, 150, 3)

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\street'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\street'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.98446683459278

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\buildings'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\buildings'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.9881332724783

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\forest'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\forest'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.89476001761338

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\mountain'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\mountain'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.8638535031847

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\glacier'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\glacier'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.78535773710482

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
# Get the dimensions of the image
dim1 = []
dim2 = []

for image_filename in os.listdir(train_path+'\\sea'):
    if image_filename != 'Thumbs.db':
        img = imread(train_path+'\\sea'+'\\'+image_filename)
    d1, d2, color = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
np.mean(dim1)
# Out:
# 149.94678979771328

# %%
np.mean(dim2)
# Out:
# 150.0

# %%
np.mean(color)
# Out:
# 3.0

# %%
len(os.listdir(train_path+'buildings'))
# Out:
# 2191

# %%
len(os.listdir(train_path+'forest'))
# Out:
# 2271

# %%
len(os.listdir(train_path+'glacier'))
# Out:
# 2404

# %%
len(os.listdir(train_path+'sea'))
# Out:
# 2274

# %%
len(os.listdir(train_path+'mountain'))
# Out:
# 2512

# %%
len(os.listdir(train_path+'street'))
# Out:
# 2382

# %%
len(os.listdir(test_path+'buildings'))
# Out:
# 437

# %%
len(os.listdir(test_path+'forest'))
# Out:
# 474

# %%
len(os.listdir(test_path+'glacier'))
# Out:
# 553

# %%
len(os.listdir(test_path+'sea'))
# Out:
# 510

# %%
len(os.listdir(test_path+'mountain'))
# Out:
# 525

# %%
len(os.listdir(test_path+'street'))
# Out:
# 501

# %%
image_shape = (150,150,3)

# %% [markdown]
# ## Data Preparation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(
                               width_shift_range=0.05, # Shift the pic width by a max of 5%
                               height_shift_range=0.05, # Shift the pic height by a max of 5%
                               shear_range=0.3, # Shear means cutting away part of the image (max 10%)
                               zoom_range=0.3, # Zoom in by 10% max
                               horizontal_flip=True, # Allo horizontal flipping
                               rescale = 1/255
                              )

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 14034 images belonging to 6 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
plt.imshow(street_img)

# %%
trans = image_gen.random_transform(street_img)
plt.imshow(trans)

# %% [markdown]
# ## Building the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Activation

# %%
model = Sequential()

model.add(Conv2D(filters=32, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=32, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=128, 
                 kernel_size=(3,3),
                 input_shape=image_shape, 
                 activation='relu',))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(64,activation='relu'))
model.add(Dense(6))
model.add(Activation('softmax'))

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 128)       73856
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=0)

# %% [markdown]
# ## Model Training

# %%
batch_size = 20

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=image_shape[:2],
                                                color_mode='rgb',
                                               batch_size=batch_size,
                                                class_mode='sparse')
# Out:
# Found 14034 images belonging to 6 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=image_shape[:2],
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='sparse')
# Out:
# Found 3000 images belonging to 6 classes.

# %%
train_image_gen.class_indices
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
results = model.fit_generator(train_image_gen,epochs=20,
                              validation_data=test_image_gen,
                             callbacks=[early_stop])
# Out:
# Epoch 1/20
# 702/702 [==============================] - 338s 482ms/step - loss: 1.1118 - accuracy: 0.5526 - val_loss: 0.9501 - val_accuracy: 0.6303
# Epoch 2/20
# 702/702 [==============================] - 313s 446ms/step - loss: 0.8446 - accuracy: 0.6780 - val_loss: 0.7673 - val_accuracy: 0.7057
# Epoch 3/20
# 702/702 [==============================] - 309s 440ms/step - loss: 0.7262 - accuracy: 0.7292 - val_loss: 0.6892 - val_accuracy: 0.7470
# Epoch 4/20
# 702/702 [==============================] - 309s 441ms/step - loss: 0.6416 - accuracy: 0.7639 - val_loss: 0.5557 - val_accuracy: 0.7970
# Epoch 5/20
# 702/702 [==============================] - 308s 439ms/step - loss: 0.5916 - accuracy: 0.7855 - val_loss: 0.5419 - val_accuracy: 0.8110
# Epoch 6/20
# 702/702 [==============================] - 324s 461ms/step - loss: 0.5470 - accuracy: 0.8055 - val_loss: 0.4927 - val_accuracy: 0.8140
# Epoch 7/20
# ...

# %% [markdown]
# ## Model Evaluation

# %%
metrics = pd.DataFrame(model.history.history)

# %%
metrics
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  1.112013  0.552587  0.950062      0.630333
# 1  0.844620  0.677996  0.767323      0.705667
# 2  0.726010  0.729158  0.689196      0.747000
# 3  0.641437  0.763859  0.555669      0.797000
# 4  0.591482  0.785521  0.541887      0.811000
# 5  0.547030  0.805472  0.492667      0.814000
# 6  0.515686  0.817586  0.564263      0.788333

# %%
metrics[['accuracy','val_accuracy']].plot()
# Out:
# <AxesSubplot:>

# %%
metrics[['loss','val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
print(model.metrics_names)
print(model.evaluate(test_image_gen,verbose=0))
# Out:
# ['loss', 'accuracy']
# [0.5532179995377858, 0.7873333]

# %%
# CODE HERE
model.save("CNN_Activity.h5")

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
predictions = model.predict(test_image_gen)

# %%
predictions
# Out:
# array([[2.33168732e-02, 1.06534932e-03, 2.99495674e-04, 6.07366055e-05,
#         1.20970835e-04, 9.75136638e-01],
#        [1.60899269e-03, 5.12678642e-04, 8.57469320e-01, 1.20658942e-01,
#         1.74736232e-02, 2.27655494e-03],
#        [5.33317179e-05, 9.99494076e-01, 9.41968246e-05, 7.26187136e-06,
#         8.47798947e-06, 3.42543848e-04],
#        ...,
#        [3.13473894e-04, 3.51384115e-05, 8.51661623e-01, 1.26161575e-01,
#         2.16050856e-02, 2.23026494e-04],
#        [4.34956513e-04, 1.46510560e-04, 9.31001641e-03, 8.68175104e-02,
#         9.02277768e-01, 1.01320783e-03],
#        [1.90962814e-02, 6.18554011e-04, 1.54772904e-04, 2.31554277e-05,
#         6.67099230e-05, 9.80040550e-01]], dtype=float32)

# %%
pred = np.argmax(predictions, axis = 1)

# %%
confusion_matrix(test_image_gen.classes,pred)
# Out:
# array([[ 40,  84,  72,  96,  65,  80],
#        [ 62,  87,  73, 106,  56,  90],
#        [ 70,  86,  83, 147,  62, 105],
#        [ 55,  91,  73, 137,  72,  97],
#        [ 49,  69, 113, 116,  68,  95],
#        [ 58,  73,  85, 116,  66, 103]], dtype=int64)

# %%
print(classification_report(test_image_gen.classes,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.12      0.09      0.10       437
#            1       0.18      0.18      0.18       474
#            2       0.17      0.15      0.16       553
#            3       0.19      0.26      0.22       525
#            4       0.17      0.13      0.15       510
#            5       0.18      0.21      0.19       501
#
#     accuracy                           0.17      3000
#    macro avg       0.17      0.17      0.17      3000
# weighted avg       0.17      0.17      0.17      3000

# %% [markdown]
# ## New Image Prediction

# %%
from tensorflow.keras.preprocessing import image

# %%
dir_path = 'C:\\School\\Anaconda\\CNNActivity\\new_sample'

# %%
os.listdir(dir_path)[50]
# Out:
# '10173.jpg'

# %%
sample = dir_path + '\\10173.jpg'

# %%
sample = image.load_img(sample,target_size=image_shape);
sample
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x198BB7CFAC8>

# %%
sample_img = image.img_to_array(sample);
sample_img.shape
# Out:
# (150, 150, 3)

# %%
sample_img = sample_img.reshape(1,150,150,3)

# %%
predicted = model.predict(sample_img)

# %%
np.argmax(predicted)
# Out:
# 0

# %%
plt.figure(figsize=(20,20))

class_names = ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']


for i in range(30):
    ax = plt.subplot(6, 5, i + 1)
    img = os.path.join(dir_path, os.listdir(dir_path)[i])
    img = image.load_img(img)
    img_array = image.img_to_array(img)     
    img_array = img_array
    input_img = np.expand_dims(img_array, axis=0)
    prediction = model.predict(input_img)
    label = np.argmax(prediction)
    plt.imshow(img)
    plt.title(class_names[label])
    plt.axis('off')
